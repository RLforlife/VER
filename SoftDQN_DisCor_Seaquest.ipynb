# %%
import numpy as np
import scipy.signal
import gym, random, pickle, os.path, math, glob
from IPython.core.debugger import set_trace
from gym.wrappers import Monitor

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.autograd as autograd
from torch.distributions import Categorical

import pdb

import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import clear_output

from atari_wrappers import make_atari, wrap_deepmind
from tensorboardX import SummaryWriter

USE_CUDA = torch.cuda.is_available()
if USE_CUDA:
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
torch.cuda.set_device(7)

# %%
class soft_DQN(nn.Module):
    def __init__(self, in_channels=4, num_actions=5, REWARD_SCALE = 1):
        """
        Initialize a deep Q-learning network as described in
        https://storage.googleapis.com/deepmind-data/assets/papers/DeepMindNature14236Paper.pdf
        Arguments:
            in_channels: number of channel of input.
                i.e The number of most recent frames stacked together as describe in the paper
            num_actions: number of action-value to output, one-to-one correspondence to action in game.
        """
        super(soft_DQN, self).__init__()        
        self.REWARD_SCALE = REWARD_SCALE
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc4 = nn.Linear(7 * 7 * 64, 512)
        self.fc5 = nn.Linear(512, num_actions)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc4(x.view(x.size(0), -1)))
        return self.fc5(x)
    
    def get_action(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc4(x.view(x.size(0), -1)))
        action_probs = F.softmax(self.fc5(x)/self.REWARD_SCALE,-1)
        action_dist = Categorical(action_probs)
        actions = action_dist.sample().view(-1, 1)
        return actions
    
class error_net(nn.Module):
    def __init__(self, in_channels=4, num_actions=5):
        """
        Initialize a deep Q-learning network as described in
        https://storage.googleapis.com/deepmind-data/assets/papers/DeepMindNature14236Paper.pdf
        Arguments:
            in_channels: number of channel of input.
                i.e The number of most recent frames stacked together as describe in the paper
            num_actions: number of action-value to output, one-to-one correspondence to action in game.
        """
        super(error_net, self).__init__()        
        self.conv1 = nn.Conv2d(in_channels, 32, kernel_size=8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, kernel_size=3, stride=1)
        self.fc4 = nn.Linear(7 * 7 * 64, 512)
        self.fc5 = nn.Linear(512, num_actions)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.fc4(x.view(x.size(0), -1)))
        return self.fc5(x)
    
def disable_gradients(network):
    for param in network.parameters():
        param.requires_grad = False

# %%
class Memory_Buffer(object):
    def __init__(self, memory_size=1000):
        self.buffer = []
        self.memory_size = memory_size
        self.next_idx = 0
        
    def push(self, state, action, reward, next_state, done):
        data = (state, action, reward, next_state, done)
        if len(self.buffer) <= self.memory_size: # buffer not full
            self.buffer.append(data)
        else: # buffer is full
            self.buffer[self.next_idx] = data
        self.next_idx = (self.next_idx + 1) % self.memory_size

    def sample(self, batch_size):
        states, actions, rewards, next_states, dones = [], [], [], [], []
        for i in range(batch_size):
            idx = random.randint(0, self.size() - 1)
            data = self.buffer[idx]
            state, action, reward, next_state, done= data
            states.append(state)
            actions.append(action)
            rewards.append(reward)
            next_states.append(next_state)
            dones.append(done)
            
            
        return np.concatenate(states), actions, rewards, np.concatenate(next_states), dones
    
    def size(self):
        return len(self.buffer)

# %%
class softDQN_DisCor_Agent: 
    def __init__(self, in_channels = 1, action_space = [], USE_CUDA = False, memory_size = 10000, lr = 1e-4, reward_scale = 1, tau_init = 10, gamma = 0.99):
        self.action_space = action_space
        self.memory_buffer = Memory_Buffer(memory_size)
        self.alpha = reward_scale
        self._tau = torch.tensor(tau_init, requires_grad=False)
        self._gamma = gamma
        self.DQN = soft_DQN(in_channels = in_channels, num_actions = action_space.n,REWARD_SCALE = reward_scale)
        self.DQN_target = soft_DQN(in_channels = in_channels, num_actions = action_space.n,REWARD_SCALE = reward_scale)
        self.DQN_target.load_state_dict(self.DQN.state_dict())
        # error net
        self.errnet = error_net(in_channels = in_channels, num_actions = action_space.n)
        self.errnet_target = error_net(in_channels = in_channels, num_actions = action_space.n)
        self.errnet_target.load_state_dict(self.errnet.state_dict())

        self.USE_CUDA = USE_CUDA
        if USE_CUDA:
            self.DQN = self.DQN.cuda()
            self.DQN_target = self.DQN_target.cuda()
            self.errnet = self.errnet.cuda()
            self.errnet_target = self.errnet_target.cuda()
            self._tau = self._tau.cuda()
        
        # disble target network gradient
        disable_gradients(self.errnet_target)        
        disable_gradients(self.DQN_target)
        # optimizer Adam
        self.optimizer = optim.Adam(list(self.DQN.parameters()) + list(self.errnet.parameters()),lr=lr)

    def observe(self, lazyframe):
        # from Lazy frame to tensor
        state =  torch.from_numpy(lazyframe._force().transpose(2,0,1)[None]/255).float()
        if self.USE_CUDA:
            state = state.cuda()
        return state

    def value(self, state):
        q_values = self.DQN(state)
        return q_values
    
    def act(self, state, t=0, explore_time=0):
        """
        random policy first, 
        then sample action according to softmax policy
        """
        if t < explore_time:
            action = self.action_space.sample()
        else:
            action = int(self.DQN.get_action(state).squeeze().cpu().detach().numpy())
        return action
        
    def compute_td_loss(self, states, actions, rewards, next_states, is_done, gamma=0.99):
        """ Compute td loss using torch operations only. Use the formula above. """
        actions = torch.tensor(actions).long()    # shape: [batch_size]
        rewards = torch.tensor(rewards, dtype =torch.float)  # shape: [batch_size]
        is_done = torch.tensor(is_done).type(torch.bool)  # shape: [batch_size]
        
        if self.USE_CUDA:
            actions = actions.cuda()
            rewards = rewards.cuda()
            is_done = is_done.cuda()
        
        imp_ws = self.calc_importance_weights(next_states, is_done)

        # get q-values for all actions in current states
        predicted_qvalues = self.DQN(states)

        # select q-values for chosen actions
        predicted_qvalues_for_actions = predicted_qvalues[
          range(states.shape[0]), actions
        ]

        # compute q-values for all actions in next states
        predicted_next_qvalues = self.DQN_target(next_states) # YOUR CODE
        # compute V*(next_states) using predicted next q-values
        next_state_values =  self.alpha*torch.logsumexp(predicted_next_qvalues/self.alpha, dim = -1) # YOUR CODE        

        # compute "target q-values" for loss - it's what's inside square parentheses in the above formula.
        target_qvalues_for_actions = rewards + gamma*next_state_values # YOUR CODE
        # at the last state we shall use simplified formula: Q(s,a) = r(s,a) since s' doesn't exist
        target_qvalues_for_actions = torch.where(
            is_done, rewards, target_qvalues_for_actions)
        # pdb.set_trace()
        # mean squared error loss to minimize with importance sampling from error model
        q_loss = (F.smooth_l1_loss(predicted_qvalues_for_actions, target_qvalues_for_actions.detach(), reduction='none')*imp_ws).sum()
        
        ## Calculate current and target errors, as well as importance weights.
        curr_errs_all = self.errnet(states)
        curr_errs = curr_errs_all[range(states.shape[0]), actions]
        
        target_errs = self.calc_target_errors(
            next_states, is_done, predicted_qvalues_for_actions, target_qvalues_for_actions)

        # calculate error loss
        err_loss = torch.mean((curr_errs - target_errs).pow(2))
        # total loss
        loss = q_loss + err_loss
        # update tau
        self._tau = (1.0 - 0.005)*self._tau + 0.005*curr_errs.detach().mean()
        logger.store(QVals = predicted_qvalues.detach().cpu().numpy(), LossQ = q_loss.item(), LossE = err_loss.item(), 
                     Current_errs = curr_errs.detach().cpu().numpy(), tau = self._tau.detach().cpu().numpy())
        return loss

    def calc_importance_weights(self, next_states, is_done):
        with torch.no_grad():
            next_actions = self.DQN_target.get_action(next_states)
            next_errs_all = self.errnet_target(next_states)
            next_errs = next_errs_all[range(next_states.shape[0]), next_actions.squeeze()]
        # Terms inside the exponent of importance weights.
        x = -(1.0 - is_done.float()) * self._gamma * next_errs / self._tau
        # Calculate self-normalized importance weights.
        imp_ws = F.softmax(x, dim=0)
        return imp_ws
    
    def calc_target_errors(self, next_states, dones, curr_qs, target_qs):
        # Calculate targets of the cumulative sum of discounted Bellman errors,
        # which is 'Delta' in the paper.
        with torch.no_grad():
            next_actions = self.DQN_target.get_action(next_states)
            next_errs_all = self.errnet_target(next_states)
            next_errs = next_errs_all[range(next_states.shape[0]), next_actions.squeeze()]

            target_errs = (curr_qs - target_qs).abs() + \
                (1.0 - dones.float()) * self._gamma * next_errs

        return target_errs

    def sample_from_buffer(self, batch_size):
        states, actions, rewards, next_states, dones = [], [], [], [], []
        for i in range(batch_size):
            idx = random.randint(0, self.memory_buffer.size() - 1)
            data = self.memory_buffer.buffer[idx]
            frame, action, reward, next_frame, done= data
            states.append(self.observe(frame))
            actions.append(action)
            rewards.append(reward)
            next_states.append(self.observe(next_frame))
            dones.append(done)
        return torch.cat(states), actions, rewards, torch.cat(next_states), dones
    
    def learn_from_experience(self, batch_size):
        if self.memory_buffer.size() > batch_size:
            states, actions, rewards, next_states, dones = self.sample_from_buffer(batch_size)
            td_loss = self.compute_td_loss(states, actions, rewards, next_states, dones)
            self.optimizer.zero_grad()
            td_loss.backward()
            for param in self.DQN.parameters():
                param.grad.data.clamp_(-1, 1)

            self.optimizer.step()
            return(td_loss.item())
        else:
            return(0)

# %%
from run_utils import setup_logger_kwargs
import itertools
import time
from logx import EpochLogger
import pdb

# Training DQN in PongNoFrameskip-v4 
# pdb.set_trace()
env_id = 'SeaquestNoFrameskip-v4'
experiment_name = "softDQN_DisCor_" + env_id
logger_kwargs = setup_logger_kwargs(experiment_name, 0)
logger = EpochLogger(**logger_kwargs)

experiment_dir = os.path.abspath(experiment_name)
monitor_path = os.path.join(experiment_dir, "monitor")
eval_monitor_path = os.path.join(experiment_dir, "eval_monitor")

log_dir = os.path.join(experiment_dir, "log")
model_path = os.path.join(experiment_dir, experiment_name+"_dict.pth.tar")
checkpoint_path = os.path.join(experiment_dir, "check_point")
env = make_atari(env_id)
env = wrap_deepmind(env, scale = False, frame_stack=True , clip_rewards= False, episode_life = True)
env_eval = make_atari(env_id)
env_eval = wrap_deepmind(env_eval, scale = False, frame_stack=True , clip_rewards= False, episode_life = False)

gamma = 0.99
steps_per_epoch = 100000
epochs = 100 # 1000
frames = steps_per_epoch * epochs# 10000000 timestamp/ 
USE_CUDA = True
learning_rate = 1e-4
max_buff = 1000000
prio_a = 0.6
prio_beta = 0.4
tau_init = 10 # initial parameter for error net

update_tar_interval = 10000
batch_size = 32
learning_start = 50000 # 50000
update_current_step = 4 # update current model every 4 steps
beta_increment_per_sampling = (1-prio_beta)/(frames/update_current_step)
record_video = True
record_video_every = 500 # video every 1000
eval_every = steps_per_epoch
save_freq = 1
num_test_episodes = 8

action_space = env.action_space
action_dim = env.action_space.n
state_dim = env.observation_space.shape[0]
state_channel = env.observation_space.shape[2]
reward_scale = 0.05
# logger.save_config(locals())
agent = softDQN_DisCor_Agent(in_channels = state_channel, action_space= action_space, USE_CUDA = USE_CUDA, lr = learning_rate, memory_size = max_buff, reward_scale = reward_scale, 
                     tau_init = tau_init, gamma = gamma)
# Set up model saving
logger.setup_pytorch_saver(agent.DQN)

def eval_episode(agent, env_eval):
    with torch.no_grad():
        for j in range(num_test_episodes):       
            frame, done, ep_ret, ep_len  = env_eval.reset(), False,0,0
            while not done:
                state_tensor = agent.observe(frame)
                action = agent.act(state_tensor, 0,0)
                frame, reward, done, _ = env_eval.step(action)
                ep_ret += reward
                ep_len += 1
            logger.store(TestEpRet=ep_ret, TestEpLen=ep_len)


if record_video:
    env = Monitor(env,
                 directory=monitor_path,
                 resume=True, mode = "training",
                 video_callable=lambda count: count % record_video_every == 0)
    env_eval = Monitor(env_eval,
                 directory=eval_monitor_path,
                 resume=True,
                 video_callable=lambda count: count % num_test_episodes == 0,
                      mode = "evaluation")

frame, ep_ret, ep_num,ep_len = env.reset(),0, 0,0
loss = 0

# tensorboard
summary_writer = SummaryWriter(log_dir = log_dir, comment= "good_makeatari")


start_time = time.time()
for i in range(frames):
    state_tensor = agent.observe(frame)
    action = agent.act(state_tensor, i, learning_start)
    
    next_frame, reward, done, _ = env.step(action)
    
    ep_ret += reward
    ep_len += 1
    agent.memory_buffer.push(frame, action, np.sign(reward), next_frame, done) # !! Clip reward by its sign
    frame = next_frame
    
    if agent.memory_buffer.size() >= learning_start:
        if i % update_current_step == 0:
            loss = agent.learn_from_experience(batch_size)
         
    if i % update_tar_interval == 0:
        agent.DQN_target.load_state_dict(agent.DQN.state_dict())
        agent.errnet_target.load_state_dict(agent.errnet.state_dict())
    
    if done:
        logger.store(EpRet=ep_ret, EpLen=ep_len)
        frame, ep_ret, ep_len = env.reset(), 0, 0
    
    if (i+1) % steps_per_epoch == 0:  
        epoch = (i+1) // steps_per_epoch

        # Save model
        if (epoch % save_freq == 0) or (epoch == epochs):
            logger.save_state({'env': env}, None)

        # Test the performance of the deterministic version of the agent.
        eval_episode(agent, env_eval)
        
        # Write to tensorboard
        summary_writer.add_scalar("Train Reward",logger.get_stats("EpRet")[0], i)
        summary_writer.add_scalar("Test Reward",logger.get_stats("TestEpRet")[0], i)
        summary_writer.add_scalar("Loss Q",logger.get_stats("LossQ")[0], i)
        summary_writer.add_scalar("Loss Error",logger.get_stats("LossE")[0], i)
        summary_writer.add_scalar("Train EpLen",logger.get_stats("EpLen")[0], i)
        summary_writer.add_scalar("Test EpLen",logger.get_stats("TestEpLen")[0], i)
        # Log info about epoch
        logger.log_tabular('Epoch', epoch)
        logger.log_tabular('EpRet', with_min_and_max=True)
        logger.log_tabular('TestEpRet', with_min_and_max=True)
        logger.log_tabular('EpLen', average_only=True)
        logger.log_tabular('TestEpLen', average_only=True)
        logger.log_tabular('TotalEnvInteracts', i)
        logger.log_tabular('QVals', with_min_and_max=True)
        logger.log_tabular('Current_errs', average_only=True)
        logger.log_tabular('LossQ', average_only=True)
        logger.log_tabular('LossE', average_only=True)
        logger.log_tabular('tau', average_only=True)
        logger.log_tabular('Time', time.time()-start_time)


        logger.dump_tabular()
        
summary_writer.close()
torch.save(agent.DQN.state_dict(), model_path)
# Out:
# /home/liang/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/liang/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/liang/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/liang/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/liang/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/liang/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Logging data to /home/liang/RL/data/softDQN_DisCor_SeaquestNoFrameskip-v4/softDQN_DisCor_SeaquestNoFrameskip-v4_s0/progress.txt
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               1 |
# |      AverageEpRet |            22.5 |
# |          StdEpRet |            34.7 |
# |          MaxEpRet |             220 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |            52.5 |
# |      StdTestEpRet |            28.2 |
# |      MaxTestEpRet |              80 |
# |      MinTestEpRet |               0 |
# |             EpLen |             132 |
# |         TestEpLen |             471 |
# | TotalEnvInteracts |           1e+05 |
# |      AverageQVals |            8.08 |
# |          StdQVals |            32.4 |
# |          MaxQVals |            1.34 |
# |          MinQVals |         -0.0377 |
# |      Current_errs |          0.0972 |
# |             LossQ |         0.00401 |
# |             LossE |         0.00732 |
# |               tau |          0.0945 |
# |              Time |        1.47e+03 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               2 |
# |      AverageEpRet |            64.7 |
# |          StdEpRet |            54.5 |
# |          MaxEpRet |             260 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             270 |
# |      StdTestEpRet |            72.1 |
# |      MaxTestEpRet |             380 |
# |      MinTestEpRet |             160 |
# |             EpLen |             217 |
# |         TestEpLen |             868 |
# | TotalEnvInteracts |           2e+05 |
# |      AverageQVals |            26.4 |
# |          StdQVals |             106 |
# |          MaxQVals |            3.25 |
# |          MinQVals |          0.0631 |
# |      Current_errs |           0.501 |
# |             LossQ |          0.0053 |
# |             LossE |          0.0171 |
# |               tau |           0.496 |
# |              Time |        4.08e+03 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               3 |
# |      AverageEpRet |            77.2 |
# |          StdEpRet |            50.7 |
# |          MaxEpRet |             220 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             258 |
# |      StdTestEpRet |            56.1 |
# |      MaxTestEpRet |             360 |
# |      MinTestEpRet |             160 |
# |             EpLen |             242 |
# |         TestEpLen |             813 |
# | TotalEnvInteracts |           3e+05 |
# |      AverageQVals |            50.2 |
# |          StdQVals |             201 |
# |          MaxQVals |            4.94 |
# |          MinQVals |         0.00738 |
# |      Current_errs |            1.24 |
# |             LossQ |         0.00911 |
# |             LossE |           0.049 |
# |               tau |            1.24 |
# |              Time |        6.74e+03 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               4 |
# |      AverageEpRet |            72.9 |
# |          StdEpRet |            48.4 |
# |          MaxEpRet |             240 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             322 |
# |      StdTestEpRet |             118 |
# |      MaxTestEpRet |             500 |
# |      MinTestEpRet |             180 |
# |             EpLen |             223 |
# |         TestEpLen |             941 |
# | TotalEnvInteracts |           4e+05 |
# |      AverageQVals |            70.3 |
# |          StdQVals |             282 |
# |          MaxQVals |             6.2 |
# |          MinQVals |           0.198 |
# |      Current_errs |            1.96 |
# |             LossQ |          0.0143 |
# |             LossE |          0.0474 |
# |               tau |            1.96 |
# |              Time |        9.32e+03 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               5 |
# |      AverageEpRet |            78.3 |
# |          StdEpRet |            50.3 |
# |          MaxEpRet |             240 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             420 |
# |      StdTestEpRet |            95.4 |
# |      MaxTestEpRet |             560 |
# |      MinTestEpRet |             280 |
# |             EpLen |             241 |
# |         TestEpLen |        1.23e+03 |
# | TotalEnvInteracts |           5e+05 |
# |      AverageQVals |            90.7 |
# |          StdQVals |             363 |
# |          MaxQVals |            7.56 |
# |          MinQVals |           0.485 |
# |      Current_errs |            2.57 |
# |             LossQ |          0.0184 |
# |             LossE |          0.0478 |
# |               tau |            2.57 |
# |              Time |         1.2e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               6 |
# |      AverageEpRet |            91.4 |
# |          StdEpRet |            57.2 |
# |          MaxEpRet |             240 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             460 |
# |      StdTestEpRet |            74.2 |
# |      MaxTestEpRet |             620 |
# |      MinTestEpRet |             380 |
# |             EpLen |             282 |
# |         TestEpLen |        1.42e+03 |
# | TotalEnvInteracts |           6e+05 |
# |      AverageQVals |             107 |
# |          StdQVals |             429 |
# |          MaxQVals |             8.6 |
# |          MinQVals |           0.497 |
# |      Current_errs |            3.15 |
# |             LossQ |          0.0222 |
# |             LossE |          0.0692 |
# |               tau |            3.14 |
# |              Time |        1.53e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               7 |
# |      AverageEpRet |             106 |
# |          StdEpRet |            62.6 |
# |          MaxEpRet |             240 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             350 |
# |      StdTestEpRet |            94.9 |
# |      MaxTestEpRet |             500 |
# |      MinTestEpRet |             200 |
# |             EpLen |             328 |
# |         TestEpLen |        1.17e+03 |
# | TotalEnvInteracts |           7e+05 |
# |      AverageQVals |             122 |
# |          StdQVals |             490 |
# |          MaxQVals |            9.58 |
# |          MinQVals |          -0.074 |
# |      Current_errs |            3.73 |
# |             LossQ |          0.0267 |
# |             LossE |          0.0976 |
# |               tau |            3.73 |
# |              Time |        1.79e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               8 |
# |      AverageEpRet |             117 |
# |          StdEpRet |            63.3 |
# |          MaxEpRet |             320 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             578 |
# |      StdTestEpRet |             164 |
# |      MaxTestEpRet |             760 |
# |      MinTestEpRet |             340 |
# |             EpLen |             365 |
# |         TestEpLen |        1.69e+03 |
# | TotalEnvInteracts |           8e+05 |
# |      AverageQVals |             137 |
# |          StdQVals |             549 |
# |          MaxQVals |            10.6 |
# |          MinQVals |          -0.378 |
# |      Current_errs |            4.26 |
# |             LossQ |          0.0315 |
# |             LossE |           0.114 |
# |               tau |            4.25 |
# |              Time |        2.21e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |               9 |
# |      AverageEpRet |             120 |
# |          StdEpRet |            68.1 |
# |          MaxEpRet |             440 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             555 |
# |      StdTestEpRet |             106 |
# |      MaxTestEpRet |             720 |
# |      MinTestEpRet |             420 |
# |             EpLen |             370 |
# |         TestEpLen |        1.67e+03 |
# | TotalEnvInteracts |           9e+05 |
# |      AverageQVals |             152 |
# |          StdQVals |             609 |
# |          MaxQVals |            11.6 |
# |          MinQVals |          -0.909 |
# |      Current_errs |            4.95 |
# |             LossQ |          0.0387 |
# |             LossE |           0.139 |
# |               tau |            4.95 |
# |              Time |        2.47e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              10 |
# |      AverageEpRet |             113 |
# |          StdEpRet |            62.5 |
# |          MaxEpRet |             260 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             395 |
# |      StdTestEpRet |             143 |
# |      MaxTestEpRet |             560 |
# |      MinTestEpRet |             140 |
# |             EpLen |             351 |
# |         TestEpLen |        1.31e+03 |
# | TotalEnvInteracts |           1e+06 |
# |      AverageQVals |             166 |
# |          StdQVals |             665 |
# |          MaxQVals |            12.5 |
# |          MinQVals |          -0.932 |
# |      Current_errs |            5.52 |
# |             LossQ |          0.0419 |
# |             LossE |           0.154 |
# |               tau |            5.51 |
# |              Time |        2.73e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              11 |
# |      AverageEpRet |             121 |
# |          StdEpRet |              61 |
# |          MaxEpRet |             240 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             505 |
# |      StdTestEpRet |            98.9 |
# |      MaxTestEpRet |             660 |
# |      MinTestEpRet |             320 |
# |             EpLen |             371 |
# |         TestEpLen |        1.45e+03 |
# | TotalEnvInteracts |         1.1e+06 |
# |      AverageQVals |             180 |
# |          StdQVals |             720 |
# |          MaxQVals |              13 |
# |          MinQVals |           -1.42 |
# |      Current_errs |            5.94 |
# |             LossQ |           0.042 |
# |             LossE |           0.168 |
# |               tau |            5.94 |
# |              Time |        3.07e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              12 |
# |      AverageEpRet |             114 |
# |          StdEpRet |            70.2 |
# |          MaxEpRet |             280 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             415 |
# |      StdTestEpRet |             121 |
# |      MaxTestEpRet |             600 |
# |      MinTestEpRet |             260 |
# |             EpLen |             355 |
# |         TestEpLen |        1.41e+03 |
# | TotalEnvInteracts |         1.2e+06 |
# |      AverageQVals |             190 |
# |          StdQVals |             763 |
# |          MaxQVals |            13.4 |
# |          MinQVals |           -1.17 |
# |      Current_errs |            6.53 |
# |             LossQ |          0.0442 |
# |             LossE |           0.202 |
# |               tau |            6.52 |
# |              Time |         3.4e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              13 |
# |      AverageEpRet |             134 |
# |          StdEpRet |            69.1 |
# |          MaxEpRet |             300 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             678 |
# |      StdTestEpRet |             114 |
# |      MaxTestEpRet |             840 |
# |      MinTestEpRet |             440 |
# |             EpLen |             404 |
# |         TestEpLen |        1.96e+03 |
# | TotalEnvInteracts |         1.3e+06 |
# |      AverageQVals |             199 |
# |          StdQVals |             796 |
# |          MaxQVals |            13.8 |
# |          MinQVals |           0.323 |
# |      Current_errs |            6.76 |
# |             LossQ |          0.0429 |
# |             LossE |           0.225 |
# |               tau |            6.76 |
# |              Time |        3.67e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              14 |
# |      AverageEpRet |             151 |
# |          StdEpRet |              64 |
# |          MaxEpRet |             280 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             595 |
# |      StdTestEpRet |             162 |
# |      MaxTestEpRet |             780 |
# |      MinTestEpRet |             420 |
# |             EpLen |             440 |
# |         TestEpLen |        1.76e+03 |
# | TotalEnvInteracts |         1.4e+06 |
# |      AverageQVals |             205 |
# |          StdQVals |             823 |
# |          MaxQVals |            14.2 |
# |          MinQVals |           0.297 |
# |      Current_errs |            7.21 |
# |             LossQ |          0.0394 |
# |             LossE |           0.214 |
# |               tau |            7.21 |
# |              Time |        3.95e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              15 |
# |      AverageEpRet |             135 |
# |          StdEpRet |            70.6 |
# |          MaxEpRet |             300 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             550 |
# |      StdTestEpRet |             129 |
# |      MaxTestEpRet |             740 |
# |      MinTestEpRet |             380 |
# |             EpLen |             405 |
# |         TestEpLen |        1.53e+03 |
# | TotalEnvInteracts |         1.5e+06 |
# |      AverageQVals |             209 |
# |          StdQVals |             839 |
# |          MaxQVals |            14.5 |
# |          MinQVals |           0.181 |
# |      Current_errs |            7.78 |
# |             LossQ |          0.0372 |
# |             LossE |           0.188 |
# |               tau |            7.77 |
# |              Time |        4.25e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              16 |
# |      AverageEpRet |             157 |
# |          StdEpRet |            72.5 |
# |          MaxEpRet |             380 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             610 |
# |      StdTestEpRet |             135 |
# |      MaxTestEpRet |             820 |
# |      MinTestEpRet |             400 |
# |             EpLen |             441 |
# |         TestEpLen |        1.63e+03 |
# | TotalEnvInteracts |         1.6e+06 |
# |      AverageQVals |             214 |
# |          StdQVals |             859 |
# |          MaxQVals |            14.8 |
# |          MinQVals |            0.14 |
# |      Current_errs |            8.39 |
# |             LossQ |          0.0342 |
# |             LossE |           0.191 |
# |               tau |            8.38 |
# |              Time |        4.52e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              17 |
# |      AverageEpRet |             171 |
# |          StdEpRet |            77.7 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             428 |
# |      StdTestEpRet |             130 |
# |      MaxTestEpRet |             680 |
# |      MinTestEpRet |             280 |
# |             EpLen |             447 |
# |         TestEpLen |        1.49e+03 |
# | TotalEnvInteracts |         1.7e+06 |
# |      AverageQVals |             218 |
# |          StdQVals |             875 |
# |          MaxQVals |            15.3 |
# |          MinQVals |           0.234 |
# |      Current_errs |            8.88 |
# |             LossQ |          0.0342 |
# |             LossE |            0.21 |
# |               tau |            8.88 |
# |              Time |        4.78e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              18 |
# |      AverageEpRet |             194 |
# |          StdEpRet |            79.6 |
# |          MaxEpRet |             580 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             595 |
# |      StdTestEpRet |             166 |
# |      MaxTestEpRet |             880 |
# |      MinTestEpRet |             340 |
# |             EpLen |             479 |
# |         TestEpLen |        1.81e+03 |
# | TotalEnvInteracts |         1.8e+06 |
# |      AverageQVals |             224 |
# |          StdQVals |             899 |
# |          MaxQVals |            15.6 |
# |          MinQVals |           0.251 |
# |      Current_errs |            8.98 |
# |             LossQ |          0.0333 |
# |             LossE |            0.19 |
# |               tau |            8.98 |
# |              Time |        5.06e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              19 |
# |      AverageEpRet |             201 |
# |          StdEpRet |            83.1 |
# |          MaxEpRet |             340 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.06e+03 |
# |      StdTestEpRet |             117 |
# |      MaxTestEpRet |        1.26e+03 |
# |      MinTestEpRet |             860 |
# |             EpLen |             474 |
# |         TestEpLen |        2.11e+03 |
# | TotalEnvInteracts |         1.9e+06 |
# |      AverageQVals |             231 |
# |          StdQVals |             927 |
# |          MaxQVals |              16 |
# |          MinQVals |           0.185 |
# |      Current_errs |            9.01 |
# |             LossQ |          0.0342 |
# |             LossE |           0.178 |
# |               tau |            9.01 |
# |              Time |        5.32e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              20 |
# |      AverageEpRet |             220 |
# |          StdEpRet |            82.3 |
# |          MaxEpRet |             380 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             748 |
# |      StdTestEpRet |             208 |
# |      MaxTestEpRet |        1.02e+03 |
# |      MinTestEpRet |             440 |
# |             EpLen |             494 |
# |         TestEpLen |        1.74e+03 |
# | TotalEnvInteracts |           2e+06 |
# |      AverageQVals |             234 |
# |          StdQVals |             936 |
# |          MaxQVals |            16.2 |
# |          MinQVals |           0.166 |
# |      Current_errs |            9.13 |
# |             LossQ |           0.031 |
# |             LossE |           0.145 |
# |               tau |            9.13 |
# |              Time |        5.59e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              21 |
# |      AverageEpRet |             229 |
# |          StdEpRet |            97.7 |
# |          MaxEpRet |             520 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |             958 |
# |      StdTestEpRet |             139 |
# |      MaxTestEpRet |         1.2e+03 |
# |      MinTestEpRet |             680 |
# |             EpLen |             474 |
# |         TestEpLen |        1.89e+03 |
# | TotalEnvInteracts |         2.1e+06 |
# |      AverageQVals |             236 |
# |          StdQVals |             944 |
# |          MaxQVals |            16.5 |
# |          MinQVals |           0.154 |
# |      Current_errs |            9.22 |
# |             LossQ |          0.0298 |
# |             LossE |           0.144 |
# |               tau |            9.22 |
# |              Time |        5.85e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              22 |
# |      AverageEpRet |             247 |
# |          StdEpRet |            94.2 |
# |          MaxEpRet |             380 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             780 |
# |      StdTestEpRet |             199 |
# |      MaxTestEpRet |        1.14e+03 |
# |      MinTestEpRet |             460 |
# |             EpLen |             480 |
# |         TestEpLen |        1.61e+03 |
# | TotalEnvInteracts |         2.2e+06 |
# |      AverageQVals |             239 |
# |          StdQVals |             959 |
# |          MaxQVals |            16.7 |
# |          MinQVals |           0.214 |
# |      Current_errs |            9.36 |
# |             LossQ |           0.028 |
# |             LossE |           0.128 |
# |               tau |            9.36 |
# |              Time |        6.13e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              23 |
# |      AverageEpRet |             250 |
# |          StdEpRet |            95.8 |
# |          MaxEpRet |             380 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |           1e+03 |
# |      StdTestEpRet |            76.8 |
# |      MaxTestEpRet |        1.16e+03 |
# |      MinTestEpRet |             880 |
# |             EpLen |             478 |
# |         TestEpLen |        2.02e+03 |
# | TotalEnvInteracts |         2.3e+06 |
# |      AverageQVals |             241 |
# |          StdQVals |             966 |
# |          MaxQVals |              17 |
# |          MinQVals |            0.18 |
# |      Current_errs |            9.17 |
# |             LossQ |          0.0264 |
# |             LossE |           0.109 |
# |               tau |            9.17 |
# |              Time |        6.39e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              24 |
# |      AverageEpRet |             248 |
# |          StdEpRet |             106 |
# |          MaxEpRet |             480 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |             952 |
# |      StdTestEpRet |             252 |
# |      MaxTestEpRet |        1.22e+03 |
# |      MinTestEpRet |             400 |
# |             EpLen |             461 |
# |         TestEpLen |        1.88e+03 |
# | TotalEnvInteracts |         2.4e+06 |
# |      AverageQVals |             245 |
# |          StdQVals |             981 |
# |          MaxQVals |            17.3 |
# |          MinQVals |           0.159 |
# |      Current_errs |            9.21 |
# |             LossQ |          0.0267 |
# |             LossE |           0.096 |
# |               tau |             9.2 |
# |              Time |        6.66e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              25 |
# |      AverageEpRet |             261 |
# |          StdEpRet |             101 |
# |          MaxEpRet |             400 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.05e+03 |
# |      StdTestEpRet |             199 |
# |      MaxTestEpRet |         1.4e+03 |
# |      MinTestEpRet |             760 |
# |             EpLen |             477 |
# |         TestEpLen |         1.8e+03 |
# | TotalEnvInteracts |         2.5e+06 |
# |      AverageQVals |             246 |
# |          StdQVals |             984 |
# |          MaxQVals |            17.2 |
# |          MinQVals |            0.16 |
# |      Current_errs |            9.15 |
# |             LossQ |           0.026 |
# |             LossE |           0.103 |
# |               tau |            9.15 |
# |              Time |        6.92e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              26 |
# |      AverageEpRet |             285 |
# |          StdEpRet |            94.9 |
# |          MaxEpRet |             400 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.27e+03 |
# |      StdTestEpRet |             131 |
# |      MaxTestEpRet |        1.48e+03 |
# |      MinTestEpRet |         1.1e+03 |
# |             EpLen |             503 |
# |         TestEpLen |        2.07e+03 |
# | TotalEnvInteracts |         2.6e+06 |
# |      AverageQVals |             247 |
# |          StdQVals |             989 |
# |          MaxQVals |            17.3 |
# |          MinQVals |           0.149 |
# |      Current_errs |            8.93 |
# |             LossQ |          0.0236 |
# |             LossE |          0.0892 |
# |               tau |            8.93 |
# |              Time |        7.25e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              27 |
# |      AverageEpRet |             284 |
# |          StdEpRet |            96.8 |
# |          MaxEpRet |             420 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |        1.02e+03 |
# |      StdTestEpRet |             180 |
# |      MaxTestEpRet |        1.32e+03 |
# |      MinTestEpRet |             720 |
# |             EpLen |             496 |
# |         TestEpLen |        1.75e+03 |
# | TotalEnvInteracts |         2.7e+06 |
# |      AverageQVals |             248 |
# |          StdQVals |             994 |
# |          MaxQVals |            17.5 |
# |          MinQVals |            0.16 |
# |      Current_errs |            8.88 |
# |             LossQ |           0.024 |
# |             LossE |           0.091 |
# |               tau |            8.88 |
# |              Time |        7.51e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              28 |
# |      AverageEpRet |             282 |
# |          StdEpRet |            95.9 |
# |          MaxEpRet |             400 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.18e+03 |
# |      StdTestEpRet |             167 |
# |      MaxTestEpRet |         1.4e+03 |
# |      MinTestEpRet |             960 |
# |             EpLen |             490 |
# |         TestEpLen |        1.96e+03 |
# | TotalEnvInteracts |         2.8e+06 |
# |      AverageQVals |             250 |
# |          StdQVals |           1e+03 |
# |          MaxQVals |            17.7 |
# |          MinQVals |           0.131 |
# |      Current_errs |            8.87 |
# |             LossQ |          0.0216 |
# |             LossE |          0.0787 |
# |               tau |            8.87 |
# |              Time |        7.86e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              29 |
# |      AverageEpRet |             300 |
# |          StdEpRet |             103 |
# |          MaxEpRet |             720 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.14e+03 |
# |      StdTestEpRet |             158 |
# |      MaxTestEpRet |        1.44e+03 |
# |      MinTestEpRet |             860 |
# |             EpLen |             506 |
# |         TestEpLen |        1.89e+03 |
# | TotalEnvInteracts |         2.9e+06 |
# |      AverageQVals |             250 |
# |          StdQVals |           1e+03 |
# |          MaxQVals |            18.5 |
# |          MinQVals |           0.162 |
# |      Current_errs |             8.9 |
# |             LossQ |          0.0207 |
# |             LossE |          0.0708 |
# |               tau |            8.91 |
# |              Time |        8.13e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              30 |
# |      AverageEpRet |             283 |
# |          StdEpRet |             107 |
# |          MaxEpRet |             400 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.06e+03 |
# |      StdTestEpRet |             240 |
# |      MaxTestEpRet |        1.38e+03 |
# |      MinTestEpRet |             700 |
# |             EpLen |             481 |
# |         TestEpLen |        1.91e+03 |
# | TotalEnvInteracts |           3e+06 |
# |      AverageQVals |             251 |
# |          StdQVals |        1.01e+03 |
# |          MaxQVals |            18.9 |
# |          MinQVals |           0.151 |
# |      Current_errs |            8.86 |
# |             LossQ |            0.02 |
# |             LossE |          0.0714 |
# |               tau |            8.86 |
# |              Time |        8.39e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              31 |
# |      AverageEpRet |             313 |
# |          StdEpRet |            95.5 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.45e+03 |
# |      StdTestEpRet |            78.1 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |        1.34e+03 |
# |             EpLen |             510 |
# |         TestEpLen |        2.25e+03 |
# | TotalEnvInteracts |         3.1e+06 |
# |      AverageQVals |             253 |
# |          StdQVals |        1.01e+03 |
# |          MaxQVals |              21 |
# |          MinQVals |           0.121 |
# |      Current_errs |             8.9 |
# |             LossQ |          0.0196 |
# |             LossE |          0.0754 |
# |               tau |             8.9 |
# |              Time |        8.68e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              32 |
# |      AverageEpRet |             306 |
# |          StdEpRet |             100 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.16e+03 |
# |      StdTestEpRet |             191 |
# |      MaxTestEpRet |        1.46e+03 |
# |      MinTestEpRet |             780 |
# |             EpLen |             504 |
# |         TestEpLen |        1.94e+03 |
# | TotalEnvInteracts |         3.2e+06 |
# |      AverageQVals |             254 |
# |          StdQVals |        1.02e+03 |
# |          MaxQVals |            18.1 |
# |          MinQVals |           0.139 |
# |      Current_errs |            8.84 |
# |             LossQ |          0.0182 |
# |             LossE |          0.0708 |
# |               tau |            8.84 |
# |              Time |        8.99e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              33 |
# |      AverageEpRet |             322 |
# |          StdEpRet |            96.2 |
# |          MaxEpRet |             680 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |        1.38e+03 |
# |      StdTestEpRet |             150 |
# |      MaxTestEpRet |         1.6e+03 |
# |      MinTestEpRet |        1.16e+03 |
# |             EpLen |             517 |
# |         TestEpLen |        2.09e+03 |
# | TotalEnvInteracts |         3.3e+06 |
# |      AverageQVals |             256 |
# |          StdQVals |        1.03e+03 |
# |          MaxQVals |            18.4 |
# |          MinQVals |           0.118 |
# |      Current_errs |            8.67 |
# |             LossQ |          0.0183 |
# |             LossE |          0.0661 |
# |               tau |            8.68 |
# |              Time |         9.3e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              34 |
# |      AverageEpRet |             314 |
# |          StdEpRet |             106 |
# |          MaxEpRet |             440 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |        1.52e+03 |
# |      StdTestEpRet |            67.8 |
# |      MaxTestEpRet |         1.6e+03 |
# |      MinTestEpRet |        1.38e+03 |
# |             EpLen |             500 |
# |         TestEpLen |        2.24e+03 |
# | TotalEnvInteracts |         3.4e+06 |
# |      AverageQVals |             257 |
# |          StdQVals |        1.03e+03 |
# |          MaxQVals |            18.6 |
# |          MinQVals |           0.124 |
# |      Current_errs |            8.51 |
# |             LossQ |          0.0184 |
# |             LossE |          0.0712 |
# |               tau |            8.51 |
# |              Time |        9.57e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              35 |
# |      AverageEpRet |             322 |
# |          StdEpRet |              98 |
# |          MaxEpRet |             560 |
# |          MinEpRet |               0 |
# |  AverageTestEpRet |         1.4e+03 |
# |      StdTestEpRet |             110 |
# |      MaxTestEpRet |        1.52e+03 |
# |      MinTestEpRet |        1.18e+03 |
# |             EpLen |             511 |
# |         TestEpLen |        2.14e+03 |
# | TotalEnvInteracts |         3.5e+06 |
# |      AverageQVals |             256 |
# |          StdQVals |        1.03e+03 |
# |          MaxQVals |            18.4 |
# |          MinQVals |           0.115 |
# |      Current_errs |            8.55 |
# |             LossQ |          0.0169 |
# |             LossE |          0.0752 |
# |               tau |            8.55 |
# |              Time |        9.89e+04 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              36 |
# |      AverageEpRet |             334 |
# |          StdEpRet |            91.6 |
# |          MaxEpRet |             460 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.51e+03 |
# |      StdTestEpRet |            46.8 |
# |      MaxTestEpRet |         1.6e+03 |
# |      MinTestEpRet |        1.42e+03 |
# |             EpLen |             523 |
# |         TestEpLen |        2.27e+03 |
# | TotalEnvInteracts |         3.6e+06 |
# |      AverageQVals |             256 |
# |          StdQVals |        1.02e+03 |
# |          MaxQVals |            18.4 |
# |          MinQVals |           0.115 |
# |      Current_errs |            8.56 |
# |             LossQ |          0.0168 |
# |             LossE |          0.0705 |
# |               tau |            8.56 |
# |              Time |        1.03e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              37 |
# |      AverageEpRet |             326 |
# |          StdEpRet |            95.4 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.06e+03 |
# |      StdTestEpRet |             174 |
# |      MaxTestEpRet |        1.34e+03 |
# |      MinTestEpRet |             700 |
# |             EpLen |             514 |
# |         TestEpLen |        1.83e+03 |
# | TotalEnvInteracts |         3.7e+06 |
# |      AverageQVals |             256 |
# |          StdQVals |        1.03e+03 |
# |          MaxQVals |            18.5 |
# |          MinQVals |           0.126 |
# |      Current_errs |            8.61 |
# |             LossQ |          0.0164 |
# |             LossE |          0.0735 |
# |               tau |            8.61 |
# |              Time |        1.07e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              38 |
# |      AverageEpRet |             330 |
# |          StdEpRet |            90.2 |
# |          MaxEpRet |             440 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.39e+03 |
# |      StdTestEpRet |             221 |
# |      MaxTestEpRet |        1.76e+03 |
# |      MinTestEpRet |        1.08e+03 |
# |             EpLen |             518 |
# |         TestEpLen |        2.12e+03 |
# | TotalEnvInteracts |         3.8e+06 |
# |      AverageQVals |             259 |
# |          StdQVals |        1.04e+03 |
# |          MaxQVals |            18.8 |
# |          MinQVals |           0.127 |
# |      Current_errs |            8.67 |
# |             LossQ |          0.0152 |
# |             LossE |          0.0656 |
# |               tau |            8.67 |
# |              Time |        1.13e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              39 |
# |      AverageEpRet |             329 |
# |          StdEpRet |            95.9 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              40 |
# |  AverageTestEpRet |        1.26e+03 |
# |      StdTestEpRet |             334 |
# |      MaxTestEpRet |        1.54e+03 |
# |      MinTestEpRet |             440 |
# |             EpLen |             513 |
# |         TestEpLen |        1.99e+03 |
# | TotalEnvInteracts |         3.9e+06 |
# |      AverageQVals |             261 |
# |          StdQVals |        1.05e+03 |
# |          MaxQVals |            18.9 |
# |          MinQVals |           0.126 |
# |      Current_errs |             8.5 |
# |             LossQ |          0.0156 |
# |             LossE |           0.064 |
# |               tau |             8.5 |
# |              Time |        1.27e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              40 |
# |      AverageEpRet |             333 |
# |          StdEpRet |            96.8 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.44e+03 |
# |      StdTestEpRet |             145 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |        1.16e+03 |
# |             EpLen |             514 |
# |         TestEpLen |        2.14e+03 |
# | TotalEnvInteracts |           4e+06 |
# |      AverageQVals |             261 |
# |          StdQVals |        1.05e+03 |
# |          MaxQVals |              19 |
# |          MinQVals |           0.131 |
# |      Current_errs |            8.44 |
# |             LossQ |          0.0146 |
# |             LossE |          0.0605 |
# |               tau |            8.44 |
# |              Time |        1.39e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              41 |
# |      AverageEpRet |             356 |
# |          StdEpRet |            80.7 |
# |          MaxEpRet |             680 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.49e+03 |
# |      StdTestEpRet |             112 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |        1.22e+03 |
# |             EpLen |             535 |
# |         TestEpLen |         2.2e+03 |
# | TotalEnvInteracts |         4.1e+06 |
# |      AverageQVals |             261 |
# |          StdQVals |        1.05e+03 |
# |          MaxQVals |              19 |
# |          MinQVals |           0.126 |
# |      Current_errs |            8.32 |
# |             LossQ |          0.0148 |
# |             LossE |          0.0636 |
# |               tau |            8.32 |
# |              Time |        1.49e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              42 |
# |      AverageEpRet |             321 |
# |          StdEpRet |             110 |
# |          MaxEpRet |             440 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.25e+03 |
# |      StdTestEpRet |             294 |
# |      MaxTestEpRet |         1.5e+03 |
# |      MinTestEpRet |             580 |
# |             EpLen |             494 |
# |         TestEpLen |        1.94e+03 |
# | TotalEnvInteracts |         4.2e+06 |
# |      AverageQVals |             261 |
# |          StdQVals |        1.05e+03 |
# |          MaxQVals |              19 |
# |          MinQVals |           0.125 |
# |      Current_errs |             8.2 |
# |             LossQ |          0.0136 |
# |             LossE |          0.0578 |
# |               tau |             8.2 |
# |              Time |        1.75e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              43 |
# |      AverageEpRet |             341 |
# |          StdEpRet |            90.6 |
# |          MaxEpRet |             460 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.46e+03 |
# |      StdTestEpRet |             130 |
# |      MaxTestEpRet |         1.6e+03 |
# |      MinTestEpRet |        1.16e+03 |
# |             EpLen |             521 |
# |         TestEpLen |        2.16e+03 |
# | TotalEnvInteracts |         4.3e+06 |
# |      AverageQVals |             262 |
# |          StdQVals |        1.05e+03 |
# |          MaxQVals |              19 |
# |          MinQVals |           0.128 |
# |      Current_errs |            8.21 |
# |             LossQ |          0.0136 |
# |             LossE |           0.055 |
# |               tau |            8.21 |
# |              Time |        1.77e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              44 |
# |      AverageEpRet |             341 |
# |          StdEpRet |            99.5 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.42e+03 |
# |      StdTestEpRet |             149 |
# |      MaxTestEpRet |        1.58e+03 |
# |      MinTestEpRet |        1.16e+03 |
# |             EpLen |             515 |
# |         TestEpLen |        2.16e+03 |
# | TotalEnvInteracts |         4.4e+06 |
# |      AverageQVals |             262 |
# |          StdQVals |        1.05e+03 |
# |          MaxQVals |            18.9 |
# |          MinQVals |           0.122 |
# |      Current_errs |            8.14 |
# |             LossQ |          0.0137 |
# |             LossE |          0.0538 |
# |               tau |            8.14 |
# |              Time |        1.79e+05 |
# ---------------------------------------
# Warning: could not pickle state_dict.
# ---------------------------------------
# |             Epoch |              45 |
# |      AverageEpRet |             352 |
# |          StdEpRet |            88.1 |
# |          MaxEpRet |             420 |
# |          MinEpRet |              20 |
# |  AverageTestEpRet |        1.57e+03 |
# |      StdTestEpRet |            45.8 |
# |      MaxTestEpRet |        1.64e+03 |
# |      MinTestEpRet |        1.48e+03 |
# |             EpLen |             527 |
# |         TestEpLen |        2.27e+03 |
# | TotalEnvInteracts |         4.5e+06 |
# |      AverageQVals |             261 |
# |          StdQVals |        1.05e+03 |
# |          MaxQVals |            18.9 |
# |          MinQVals |           0.125 |
# |      Current_errs |            7.88 |
# |             LossQ |          0.0134 |
# |             LossE |           0.053 |
# |               tau |            7.88 |
# |              Time |        1.81e+05 |
# ---------------------------------------

# %%
agent.DQN(state_tensor).cpu().detach().numpy().argmax(1)[0]
# Out:
# 2
